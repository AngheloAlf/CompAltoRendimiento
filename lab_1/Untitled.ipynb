# %%
import numpy as np
import matplotlib.pyplot as plt

x = ["2x2", "4x4", "16x16", "128x72", "256x144", "1280x720"]
cpu = np.log([25.660000, 
120.217003, 
277.420990, 
94.823997, 
55.346001, 
51.855999])
gpu = np.log([
403.419098,
136.335037,
8.287904,
0.307552,
0.238592,
0.413600
])

fig = plt.figure()
fig.suptitle('Tiempo vs Tamaño de imagen')# , fontsize=20)
plt.xlabel('Dimensiones de la imagen [px*px]')#, fontsize=18)
plt.ylabel('Tiempo [ln(ms)]')#, fontsize=16)

plt.plot(x, cpu, 'r', label="CPU")
plt.plot(x, gpu, 'b', label="CUDA")
plt.legend()
plt.show()
fig.savefig('grafico_bonito.png')
