# %%
import numpy as np
import matplotlib.pyplot as plt

x = ([str(2**i) for i in range(10)])
        
pr1 = np.log([8.000000, 8.000000, 7.000000, 8.000000, 8.000000, 8.000000, 7.000000, 8.000000, 7.000000, 10.000000])
pr2 = np.log([0.189280, 0.243776, 0.540736, 0.862208, 1.106944, 1.640448, 2.484288, 1.632352, 1.471776, 1.596416])
pr3 = np.log([0.271648, 0.272704, 0.359424, 0.905920, 1.393536, 1.667072, 2.209632, 0.924800, 0.813088, 1.048576])
pr4 = np.log([0.930592, 0.521120, 0.338112, 0.269312, 0.290336, 0.268256, 0.268256, 0.266144, 0.263840, 0.259840])
        
fig = plt.figure()
fig.suptitle('Tiempo vs Tamaño de imagen')# , fontsize=20)
plt.xlabel('Tamaño del x')#, fontsize=18)
plt.ylabel('Tiempo [ln(ms)]')#, fontsize=16)

plt.plot(x, pr1, 'r', label="CPU - Pregunta1")
plt.plot(x, pr2, 'b', label="CUDA - Pregunta2")
plt.plot(x, pr3, 'g', label="CUDA - Pregunta3")
plt.plot(x, pr4, 'y', label="CUDA - Pregunta4")
plt.legend()
plt.show()
fig.savefig('grafico_bonito.png')
